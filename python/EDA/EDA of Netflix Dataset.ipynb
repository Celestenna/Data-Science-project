# %% [markdown]
# # Exploratory Data Analysis of Netflix Dataset
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# **Exploratory data analysis (EDA)** is used by data scientists to analyze and investigate data sets and summarize their main characteristics, often employing data visualization methods. It helps determine how best to manipulate data sources to get the answers you need, making it easier for data scientists to discover patterns, spot anomalies, test a hypothesis, or check assumptions.

# %% [markdown]
# ## Import Libraries

# %%
import numpy as np # for numerical
import pandas as pd # for data analysis
import matplotlib.pyplot as plt # for visualization
import seaborn as sns # for visualization

# %% [markdown]
# ## Load Dataset

# %%
# read_csv()
netflix_df = pd.read_csv("netflix1.csv")

# %%
netflix_df.head()   # return the first 5 records
# Out:
#   show_id     type                             title         director  \
# 0      s1    Movie              Dick Johnson Is Dead  Kirsten Johnson
# 1      s3  TV Show                         Ganglands  Julien Leclercq
# 2      s6  TV Show                     Midnight Mass    Mike Flanagan
# 3     s14    Movie  Confessions of an Invisible Girl    Bruno Garotti
# 4      s8    Movie                           Sankofa     Haile Gerima
#
#          country date_added  release_year rating  duration  \
# 0  United States  9/25/2021          2020  PG-13    90 min
# 1         France  9/24/2021          2021  TV-MA  1 Season
# 2  United States  9/24/2021          2021  TV-MA  1 Season
# 3         Brazil  9/22/2021          2021  TV-PG    91 min
# 4  United States  9/24/2021          1993  TV-MA   125 min
#
#                                            listed_in
# 0                                      Documentaries
# 1  Crime TV Shows, International TV Shows, TV Act...
# ...

# %%
netflix_df.tail() # returns the last 5
# Out:
#      show_id     type               title   director        country  \
# 8785   s8797  TV Show          Yunus Emre  Not Given         Turkey
# 8786   s8798  TV Show           Zak Storm  Not Given  United States
# 8787   s8801  TV Show  Zindagi Gulzar Hai  Not Given       Pakistan
# 8788   s8784  TV Show                Yoko  Not Given       Pakistan
# 8789   s8786  TV Show                 YOM  Not Given       Pakistan
#
#       date_added  release_year rating   duration  \
# 8785   1/17/2017          2016  TV-PG  2 Seasons
# 8786   9/13/2018          2016  TV-Y7  3 Seasons
# 8787  12/15/2016          2012  TV-PG   1 Season
# 8788   6/23/2018          2016   TV-Y   1 Season
# 8789    6/7/2018          2016  TV-Y7   1 Season
#
#                                               listed_in
# 8785                  International TV Shows, TV Dramas
# 8786                                           Kids' TV
# 8787  International TV Shows, Romantic TV Shows, TV ...
# ...

# %%
n_rows = netflix_df.shape[0]
n_cols = netflix_df.shape[1]

# %%
n_rows = netflix_df.shape[0]
n_cols = netflix_df.shape[1]

print(f'The netflix dataset contains {n_rows} rows and {n_cols} columns')
# Out:
# The netflix dataset contains 8790 rows and 10 columns

# %% [markdown]
# ### Check for Duplicates  The dataset does not contain duplicate

# %%
netflix_df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ### To remove dupicate

# %%
## netflix_df.drop_duplicates(inplace=True)

# %%
netflix_df.columns
# Out:
# Index(['show_id', 'type', 'title', 'director', 'country', 'date_added',
#        'release_year', 'rating', 'duration', 'listed_in'],
#       dtype='object')

# %%
# Info of the data
netflix_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8790 entries, 0 to 8789
# Data columns (total 10 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8790 non-null   object
#  1   type          8790 non-null   object
#  2   title         8790 non-null   object
#  3   director      8790 non-null   object
#  4   country       8790 non-null   object
#  5   date_added    8790 non-null   object
#  6   release_year  8790 non-null   int64
#  7   rating        8790 non-null   object
#  8   duration      8790 non-null   object
#  9   listed_in     8790 non-null   object
# dtypes: int64(1), object(9)
# memory usage: 686.8+ KB

# %%
# to index a column
netflix_df["director"]
# Out:
# 0       Kirsten Johnson
# 1       Julien Leclercq
# 2         Mike Flanagan
# 3         Bruno Garotti
# 4          Haile Gerima
#              ...
# 8785          Not Given
# 8786          Not Given
# 8787          Not Given
# 8788          Not Given
# 8789          Not Given
# Name: director, Length: 8790, dtype: object

# %%
# max(to see total no of not given)
netflix_df[netflix_df["director"] =="Not Given"]
# Out:
#      show_id     type                            title   director  \
# 12      s852    Movie                 99 Songs (Tamil)  Not Given
# 17        s4  TV Show            Jailbirds New Orleans  Not Given
# 18       s15  TV Show  Crime Stories: India Detectives  Not Given
# 33       s20  TV Show                           Jaguar  Not Given
# 34       s32  TV Show               Chicago Party Aunt  Not Given
# ...      ...      ...                              ...        ...
# 8785   s8797  TV Show                       Yunus Emre  Not Given
# 8786   s8798  TV Show                        Zak Storm  Not Given
# 8787   s8801  TV Show               Zindagi Gulzar Hai  Not Given
# 8788   s8784  TV Show                             Yoko  Not Given
# 8789   s8786  TV Show                              YOM  Not Given
#
#             country  date_added  release_year rating   duration  \
# 12         Pakistan   5/21/2021          2021  TV-14    131 min
# ...

# %%
# describtive statistics
netflix_df.describe()
# Out:
#        release_year
# count   8790.000000
# mean    2014.183163
# std        8.825466
# min     1925.000000
# 25%     2013.000000
# 50%     2017.000000
# 75%     2019.000000
# max     2021.000000

# %%
netflix_df.describe(include = 'all')
# Out:
#        show_id   type  title   director        country date_added  \
# count     8790   8790   8790       8790           8790       8790
# unique    8790      2   8787       4528             86       1713
# top         s1  Movie  9-Feb  Not Given  United States   1/1/2020
# freq         1   6126      2       2588           3240        110
# mean       NaN    NaN    NaN        NaN            NaN        NaN
# std        NaN    NaN    NaN        NaN            NaN        NaN
# min        NaN    NaN    NaN        NaN            NaN        NaN
# 25%        NaN    NaN    NaN        NaN            NaN        NaN
# 50%        NaN    NaN    NaN        NaN            NaN        NaN
# 75%        NaN    NaN    NaN        NaN            NaN        NaN
# max        NaN    NaN    NaN        NaN            NaN        NaN
#
#         release_year rating  duration                     listed_in
# count    8790.000000   8790      8790                          8790
# ...

# %%
netflix_df['duration']
# Out:
# 0          90 min
# 1        1 Season
# 2        1 Season
# 3          91 min
# 4         125 min
#           ...
# 8785    2 Seasons
# 8786    3 Seasons
# 8787     1 Season
# 8788     1 Season
# 8789     1 Season
# Name: duration, Length: 8790, dtype: object

# %%
netflix_df['release_year'].dtype
# Out:
# dtype('int64')

# %%
netflix_df['date_added'].dtype
# Out:
# dtype('O')

# %%
# the date added need to conver  to date format

pd.to_datetime(netflix_df["date_added"])
# Out:
# 0      2021-09-25
# 1      2021-09-24
# 2      2021-09-24
# 3      2021-09-22
# 4      2021-09-24
#           ...
# 8785   2017-01-17
# 8786   2018-09-13
# 8787   2016-12-15
# 8788   2018-06-23
# 8789   2018-06-07
# Name: date_added, Length: 8790, dtype: datetime64[ns]

# %%
netflix_df["date_added"] = pd.to_datetime(netflix_df["date_added"])

# %%
netflix_df["date_added"].dtype
# Out:
# dtype('<M8[ns]')

# %% [markdown]
# ## Check for missing values

# %%
netflix_df.isnull()
# Out:
#       show_id   type  title  director  country  date_added  release_year  \
# 0       False  False  False     False    False       False         False
# 1       False  False  False     False    False       False         False
# 2       False  False  False     False    False       False         False
# 3       False  False  False     False    False       False         False
# 4       False  False  False     False    False       False         False
# ...       ...    ...    ...       ...      ...         ...           ...
# 8785    False  False  False     False    False       False         False
# 8786    False  False  False     False    False       False         False
# 8787    False  False  False     False    False       False         False
# 8788    False  False  False     False    False       False         False
# 8789    False  False  False     False    False       False         False
#
#       rating  duration  listed_in
# 0      False     False      False
# ...

# %%
netflix_df.isnull().sum()
# Out:
# show_id         0
# type            0
# title           0
# director        0
# country         0
# date_added      0
# release_year    0
# rating          0
# duration        0
# listed_in       0
# dtype: int64

# %%
netflix_df.sample(7)
# Out:
#      show_id   type                   title                    director  \
# 4462   s6200  Movie                Automata                 Gabe Ibáñez
# 5121   s7043  Movie          I Am Vengeance                 Ross Boyask
# 2001   s2468  Movie      I'm No Longer Here  Fernando Frías de la Parra
# 251     s180  Movie     The Nutty Professor                 Tom Shadyac
# 407     s296  Movie        The Paper Tigers               Quoc Bao Tran
# 3433   s4736  Movie  Tere Naal Love Ho Gaya               Mandeep Kumar
# 2870   s3873  Movie    Knock Down The House                Rachel Lears
#
#              country date_added  release_year rating duration  \
# 4462        Bulgaria 2017-09-08          2014      R  110 min
# 5121  United Kingdom 2018-12-22          2018      R   93 min
# 2001          Mexico 2020-05-27          2019  TV-MA  112 min
# 251    United States 2021-09-01          1996  PG-13   95 min
# 407    United States 2021-08-07          2021  PG-13  111 min
# ...

# %% [markdown]
# ## Data Exploration

# %% [markdown]
# Understanding the `loc`; location based
# and
# `iloc`;integer-location based

# %%
# Return all movies from india

netflix_df.loc[:,["country"]]
# Out:
#             country
# 0     United States
# 1            France
# 2     United States
# 3            Brazil
# 4     United States
# ...             ...
# 8785         Turkey
# 8786  United States
# 8787       Pakistan
# 8788       Pakistan
# 8789       Pakistan
#
# [8790 rows x 1 columns]

# %%
india_mask = (netflix_df["country"] =="India")

indian_movies = netflix_df[india_mask]

indian_movies.head(2)
# Out:
#   show_id   type                            title     director country  \
# 7    s939  Movie  Motu Patlu in the Game of Zones  Suhas Kadav   India
# 9    s940  Movie         Motu Patlu in Wonderland  Suhas Kadav   India
#
#   date_added  release_year rating duration  \
# 7 2021-05-01          2019  TV-Y7   87 min
# 9 2021-05-01          2013  TV-Y7   76 min
#
#                                            listed_in
# 7  Children & Family Movies, Comedies, Music & Mu...
# 9         Children & Family Movies, Music & Musicals

# %% [markdown]
# 1. Count of movies by type

# %%
netflix_df['type']
# Out:
# 0         Movie
# 1       TV Show
# 2       TV Show
# 3         Movie
# 4         Movie
#          ...
# 8785    TV Show
# 8786    TV Show
# 8787    TV Show
# 8788    TV Show
# 8789    TV Show
# Name: type, Length: 8790, dtype: object

# %%
netflix_df['type'].unique()
# Out:
# array(['Movie', 'TV Show'], dtype=object)

# %%
netflix_df['type'].value_counts()
# Out:
# Movie      6126
# TV Show    2664
# Name: type, dtype: int64

# %%
# to put in a dataframe
count_by_type= netflix_df['type'].value_counts().reset_index()
count_by_type
# Out:
#      index  type
# 0    Movie  6126
# 1  TV Show  2664

# %%
# to change name
count_by_type.rename(columns={"index":"type","type":"count"})
# Out:
#       type  count
# 0    Movie   6126
# 1  TV Show   2664

# %%
count_by_type.rename(index={0:1,1:2})
# Out:
#      index  type
# 1    Movie  6126
# 2  TV Show  2664

# %%
count_by_type
# Out:
#      index  type
# 0    Movie  6126
# 1  TV Show  2664

# %%
count_by_type= netflix_df['type'].value_counts().reset_index().rename(columns={"index":"type","type":"count"})

# %%
count_by_type
# Out:
#       type  count
# 0    Movie   6126
# 1  TV Show   2664

# %%
plt.figure(figsize=(20,6))
plt.pie(x=count_by_type['count'], labels=count_by_type['type'])
# Out:
# ([<matplotlib.patches.Wedge at 0x1d376310970>,
# ...
#  [Text(-0.6379461266276708, 0.8961164765368127, 'Movie'),
#   Text(0.6379461266276707, -0.8961164765368128, 'TV Show')])

# %%
plt.pie(x=count_by_type['count'], labels=count_by_type['type'], autopct='%1.1f%%', colors=['forestgreen','orange'])

plt.title("Count of Movie by Type")
plt.show()

# %% [markdown]
# 2. Count of Movies by countries

# %%
netflix_df['country'].value_counts()
# Out:
# United States     3240
# India             1057
# United Kingdom     638
# Pakistan           421
# Not Given          287
#                   ...
# Iran                 1
# West Germany         1
# Greece               1
# Zimbabwe             1
# Soviet Union         1
# Name: country, Length: 86, dtype: int64

# %%
count_by_country= netflix_df['country'].value_counts().reset_index()
count_by_country
# Out:
#              index  country
# 0    United States     3240
# 1            India     1057
# 2   United Kingdom      638
# 3         Pakistan      421
# 4        Not Given      287
# ..             ...      ...
# 81            Iran        1
# 82    West Germany        1
# 83          Greece        1
# 84        Zimbabwe        1
# 85    Soviet Union        1
#
# [86 rows x 2 columns]

# %%
top_10_count_by_country= netflix_df['country'].value_counts().reset_index().rename(columns={"index":"country","country":"count"})[0:10]
top_10_count_by_country
# Out:
#           country  count
# 0   United States   3240
# 1           India   1057
# 2  United Kingdom    638
# 3        Pakistan    421
# 4       Not Given    287
# 5          Canada    271
# 6           Japan    259
# 7     South Korea    214
# 8          France    213
# 9           Spain    182

# %%
top_10_count_by_country
# Out:
#           country  count
# 0   United States   3240
# 1           India   1057
# 2  United Kingdom    638
# 3        Pakistan    421
# 4       Not Given    287
# 5          Canada    271
# 6           Japan    259
# 7     South Korea    214
# 8          France    213
# 9           Spain    182

# %%
plt.bar(top_10_count_by_country['country'],top_10_count_by_country['count'])

plt.title("Count of Movies by Country")
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x="country", y="count", data=top_10_count_by_country)
plt.title("Count of Movies by Country")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 3. Total number of movies by country and type

# %%
count_by_country_type = netflix_df[["country","type"]].value_counts().reset_index().rename(columns={0:"total_num"})[0:10]
count_by_country_type
# Out:
#           country     type  total_num
# 0   United States    Movie       2395
# 1           India    Movie        976
# 2   United States  TV Show        845
# 3  United Kingdom    Movie        387
# 4        Pakistan  TV Show        350
# 5       Not Given    Movie        257
# 6  United Kingdom  TV Show        251
# 7          Canada    Movie        187
# 8           Japan  TV Show        172
# 9     South Korea  TV Show        165

# %%
sns.barplot(x="country", y="total_num", data=count_by_country_type, hue='type')
plt.title("Total Movies by Country and Type")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 4. Total number of movies by director and type

# %%
count_by_director_type= netflix_df[["director","type"]].value_counts().reset_index().rename(columns={0:"count"})[0:10]

count_by_director_type
# Out:
#                  director     type  count
# 0               Not Given  TV Show   2415
# 1               Not Given    Movie    173
# 2           Rajiv Chilaka    Movie     19
# 3  Raúl Campos, Jan Suter    Movie     18
# 4             Suhas Kadav    Movie     16
# 5            Marcus Raboy    Movie     15
# 6     Alastair Fothergill  TV Show     14
# 7               Jay Karas    Movie     14
# 8     Cathy Garcia-Molina    Movie     13
# 9         Youssef Chahine    Movie     12

# %%
sns.barplot(x="director", y="count", data=count_by_director_type, hue='type')
plt.title("Count of Movies by director and Type")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 5. Top 10 directors by number of moveies

# %%
count_by_director= netflix_df["director"].value_counts().reset_index().rename(columns={'index':"director","director":"count"})[1:10]
count_by_director
# Out:
#                  director  count
# 1           Rajiv Chilaka     20
# 2     Alastair Fothergill     18
# 3  Raúl Campos, Jan Suter     18
# 4             Suhas Kadav     16
# 5            Marcus Raboy     16
# 6               Jay Karas     14
# 7     Cathy Garcia-Molina     13
# 8         Martin Scorsese     12
# 9         Youssef Chahine     12

# %%
sns.barplot(x="director", y="count", data=count_by_director)
plt.title("Count of Movies by director")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# The numbers of movies by non provided directors is 2588 and it will be excluded from my visual

# %% [markdown]
# 6. Top 10 movie directors

# %%
 movie_mask=netflix_df[netflix_df["type"] =="Movie"]['director'].value_counts().reset_index().rename(columns={"index":"director","director":"count"})[0:10]
#netflix_df["director"].value_counts().reset_index()
movie_mask
# Out:
#                  director  count
# 0               Not Given    173
# 1           Rajiv Chilaka     19
# 2  Raúl Campos, Jan Suter     18
# 3             Suhas Kadav     16
# 4            Marcus Raboy     15
# 5               Jay Karas     14
# 6     Cathy Garcia-Molina     13
# 7         Martin Scorsese     12
# 8         Youssef Chahine     12
# 9             Jay Chapman     12

# %%
sns.barplot(x="director", y="count", data=count_by_director)
plt.title("Movie Mask")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 7.Top 10 TV show director

# %%
tv_mask = netflix_df[netflix_df["type"] =="TV Show"]["director"].value_counts().reset_index().rename(columns={"index":"director","director":"count"})[1:11]
tv_mask
# Out:
#                         director  count
# 1            Alastair Fothergill     14
# 2   Mark Thornton, Todd Kauffman      5
# 3                    Stan Lathan      3
# 4                    Hsu Fu-chun      2
# 5                 Iginio Straffi      2
# 6                    Shin Won-ho      2
# 7                      Ken Burns      2
# 8                Rob Seidenglanz      2
# 9                Quek Shio-chuan      1
# 10               Soumendra Padhi      1

# %%
sns.barplot(y="director", x="count", data=count_by_director)
plt.title("TV Mask")
plt.xticks(rotation=90)
plt.show()

# %%
sns.barplot(x="director", y="count", data=count_by_director, orient)
plt.title("TV Mask")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 8. Total numbers of movie in each year

# %%
count_by_movie_by_year= netflix_df[["release_year"]].value_counts().reset_index().rename(columns={0:"count"}).sort_values('release_year')

count_by_movie_by_year
# Out:
#     release_year  count
# 73          1925      1
# 65          1942      2
# 59          1943      3
# 55          1944      3
# 52          1945      4
# ..           ...    ...
# 2           2017   1030
# 0           2018   1146
# 1           2019   1030
# 3           2020    953
# 5           2021    592
#
# [74 rows x 2 columns]

# %%
sns.lineplot(x="release_year", y="count", data=count_by_movie_by_year)
plt.title("BY Year")
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# 9. Total movies by rating

# %%
count_by_movie_by_rating= netflix_df[["rating"]].value_counts().reset_index().rename(columns={0:"count"})
count_by_movie_by_rating
# Out:
#       rating  count
# 0      TV-MA   3205
# 1      TV-14   2157
# 2      TV-PG    861
# 3          R    799
# 4      PG-13    490
# 5      TV-Y7    333
# 6       TV-Y    306
# 7         PG    287
# 8       TV-G    220
# 9         NR     79
# 10         G     41
# 11  TV-Y7-FV      6
# 12     NC-17      3
# 13        UR      3

# %%
sns.barplot(x="rating", y="count", data=count_by_movie_by_rating)
plt.title("BY Year")
plt.xticks(rotation=90)
plt.show()
